# %%
# !pip install ultralytics
from ultralytics import YOLO

model = YOLO('yolo11n.pt')
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 26.4 MB/s eta 0:00:00
# ...
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...

# %%
from google.colab import files

uploaded = files.upload()  # selecciona aquí 5 fotos tuyas o un video corto
# Out:
#      <input type="file" id="files-980b3878-bc1f-4ae3-a326-6b402c5c144f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-980b3878-bc1f-4ae3-a326-6b402c5c144f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
results = model.predict(source=list(uploaded.keys()), save=True)
# Out:
# 0: 640x640 1 bed, 1 teddy bear, 246.2ms
# 1: 640x640 1 fork, 1 sandwich, 1 dining table, 246.2ms
# 2: 640x640 1 dog, 1 chair, 246.2ms
# 3: 640x640 1 dog, 1 laptop, 246.2ms
# 4: 640x640 1 dog, 246.2ms
# Speed: 11.7ms preprocess, 246.2ms inference, 8.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to /content/runs/detect/predict

# %%
# !zip -r resultados_yolo.zip runs/detect/
files.download('resultados_yolo.zip')
# Out:
#   adding: runs/detect/ (stored 0%)
#   adding: runs/detect/predict/ (stored 0%)
#   adding: runs/detect/predict/Imagen de WhatsApp 2025-11-08 a las 10.55.31_a9031c17.jpg (deflated 5%)
#   adding: runs/detect/predict/Imagen de WhatsApp 2025-11-08 a las 10.55.32_a94a1735.jpg (deflated 3%)
#   adding: runs/detect/predict/Imagen de WhatsApp 2025-11-08 a las 10.55.43_461ae97f.jpg (deflated 3%)
#   adding: runs/detect/predict/Imagen de WhatsApp 2025-11-08 a las 10.55.32_43228c40.jpg (deflated 5%)
#   adding: runs/detect/predict/Imagen de WhatsApp 2025-11-08 a las 10.55.31_578e5d72.jpg (deflated 4%)
